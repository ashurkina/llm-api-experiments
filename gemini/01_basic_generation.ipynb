# %% [markdown]
# ## GEMINI API Experimentation

# %%
from google import genai
from dotenv import load_dotenv
import os

load_dotenv()

client = genai.Client(
    api_key=os.getenv("GEMINI_API_KEY")
)

# %%
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="Explain what prompt engineering is."
)

print(response.text)
# Out:
# **Prompt engineering** is the art and science of designing, optimizing, and refining the input (called "prompts") you give to large language models (LLMs) and other generative AI models, in order to elicit the desired, high-quality, and specific outputs.
#
# Think of it like giving instructions to a very intelligent but literal assistant. If you give vague or poorly structured instructions, you might get a vague, irrelevant, or even incorrect result. But if you provide clear, precise, and well-structured instructions, the assistant can leverage its full capabilities to give you exactly what you need.
#
# ### Why is Prompt Engineering Important?
#
# LLMs are incredibly powerful, but their output is highly dependent on the quality of the input. Prompt engineering helps to:
#
# 1.  **Improve Accuracy and Relevance:** Get outputs that are precisely what you asked for, reducing generic or off-topic responses.
# 2.  **Achieve Consistency:** Ensure the model behaves predictably and provides similar quality output across different queries or sessions.
# 3.  **Unlock Advanced Capabilities:** Guide the model to perform complex tasks like multi-step reasoning, code generation, creative writing, or data analysis.
# 4.  **Reduce "Hallucinations":** Minimize instances where the model generates factually incorrect or nonsensical information.
# 5.  **Increase Efficiency:** Get desired results faster, reducing the need for extensive post-processing or multiple attempts.
# 6.  **Control Output Format and Style:** Specify length, tone, structure (e.g., bullet points, JSON, essay format), and other stylistic elements.
#
# ### Key Aspects and Techniques of Prompt Engineering:
#
# Prompt engineering often involves an iterative process of experimentation and refinement. Some common techniques include:
#
# 1.  **Clarity and Specificity:** Being unambiguous and precise with your request.
#     *   *Poor:* "Write about dogs."
#     *   *Good:* "Write a 200-word blog post for a pet adoption agency about the top 3 benefits of adopting a senior dog, using a heartwarming and encouraging tone."
#
# 2.  **Context Provision:** Giving the AI relevant background information it needs to understand the request fully.
#     *   "Given the following user review: '[review text]', summarize the main positive and negative points."
#
# 3.  **Role-Playing:** Instructing the AI to adopt a specific persona or role to influence its response style and content.
#     *   "Act as a professional copywriter specializing in sustainable fashion. Write a social media post promoting our new line of organic cotton shirts."
#
# 4.  **Constraints and Format Specification:** Defining what the output should or shouldn't include, its length, and its structure.
#     *   "List 5 unique gift ideas for a gardener, each under $50. Format your response as a numbered list with a brief description for each item."
#
# 5.  **Few-Shot Prompting (Providing Examples):** Giving the AI a few examples of desired input/output pairs to guide its understanding. This is especially useful for specific styles or transformations.
#     *   "Here are some examples of converting movie titles to emojis:
#         -   'The Lion King' -> 🦁👑
#         -   'Star Wars' -> ⭐⚔️
#         Now, convert 'Finding Nemo' ->"
#
# 6.  **Chain-of-Thought Prompting:** Breaking down a complex problem into a series of smaller, logical steps, often by explicitly asking the model to "think step by step" or show its reasoning. This helps with complex reasoning tasks.
#     *   "Solve the following math problem: [problem]. First, identify the operations needed. Second, perform each operation in order. Third, state the final answer."
#
# 7.  **Iterative Refinement:** It's rare to get the perfect prompt on the first try. Prompt engineers continually test, evaluate, and modify their prompts based on the AI's responses.
#
# ### Who Uses Prompt Engineering?
#
# Anyone who regularly interacts with LLMs for specific outcomes can benefit from prompt engineering. This includes:
#
# *   **Developers and AI Engineers** building applications on top of LLMs.
# *   **Content Creators and Marketers** generating ideas, drafts, and copy.
# *   **Researchers** using LLMs for data analysis or information extraction.
# *   **Product Managers** designing AI features.
# *   **Anyone** seeking to get the most out of tools like ChatGPT, Claude, Gemini, or custom LLM deployments.
#
# In essence, prompt engineering is becoming a fundamental skill for effectively harnessing the power of generative AI.

# %%
for model in client.models.list():
    print(model.name)
# Out:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-4-26b-a4b-it
# models/gemma-4-31b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-3-pro-preview
# models/gemini-3-flash-preview
# models/gemini-3.1-pro-preview
# models/gemini-3.1-pro-preview-customtools
# models/gemini-3.1-flash-lite-preview
# models/gemini-3.1-flash-lite
# models/gemini-3-pro-image-preview
# models/gemini-3-pro-image
# models/nano-banana-pro-preview
# models/gemini-3.1-flash-image-preview
# models/gemini-3.1-flash-image
# models/gemini-3.5-flash
# models/lyria-3-clip-preview
# models/lyria-3-pro-preview
# models/gemini-3.1-flash-tts-preview
# models/gemini-robotics-er-1.5-preview
# models/gemini-robotics-er-1.6-preview
# models/gemini-2.5-computer-use-preview-10-2025
# models/antigravity-preview-05-2026
# models/deep-research-max-preview-04-2026
# models/deep-research-preview-04-2026
# models/deep-research-pro-preview-12-2025
# models/gemini-embedding-001
# models/gemini-embedding-2-preview
# models/gemini-embedding-2
# models/aqa
# models/imagen-4.0-generate-001
# models/imagen-4.0-ultra-generate-001
# models/imagen-4.0-fast-generate-001
# models/veo-2.0-generate-001
# models/veo-3.0-generate-001
# models/veo-3.0-fast-generate-001
# models/veo-3.1-generate-preview
# models/veo-3.1-fast-generate-preview
# models/veo-3.1-lite-generate-preview
# models/gemini-2.5-flash-native-audio-latest
# models/gemini-2.5-flash-native-audio-preview-09-2025
# models/gemini-2.5-flash-native-audio-preview-12-2025
# models/gemini-3.1-flash-live-preview
# models/gemini-3.5-live-translate-preview
